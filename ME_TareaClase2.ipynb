# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
nombres=["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style",
        "drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type",
        "num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm",
        "city-mpg","highway-mpg","price"]
dataOri=pd.read_csv("D:\MaestriaEA\Metodos estadísticos avanzados\Clase2\imports-85.data",delimiter=",",names=nombres)

# %%
dataDummis=pd.get_dummies(dataOri)

# %%
data0["peak-rpm"]=data0["peak-rpm"].astype(np.float64)

# %%
dataOri["price"]=dataOri["price"].astype(np.float64)

# %%
dataOri["price0"]=dataOri["price"]
#dataOri[(dataOri["price0"]>=0)&(dataOri["price0"]<=5000)]="b"
#dataOri[(dataOri["price0"]>5000)&(dataOri["price0"]<=8000)]="r"
#dataOri[(dataOri["price0"]>8000)&(dataOri["price0"]<=10000)]="k"
dataOri[(dataOri["price0"]>10000)]["price0"]="y"
dataOri["price0"]
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price0, Length: 205, dtype: float64

# %%
dataOri["price0"].iloc[1:4]
# Out:
# 1    16500.0
# 2    16500.0
# 3    13950.0
# Name: price0, dtype: float64

# %%
vec=dataOri["price"].value_counts()
vec.keys()
# Out:
# Index([  15342,  '8921', '18150',  '8845',  '8495',  '7609',  '6692',  '6229',
#         '7957',  '7775',
#        ...
#        '28176', '31600', '34184', '35056', '40960', '45400', '16503',  '5389',
#         '6189', '22625'],
#       dtype='object', length=187)

# %%
vec.value_counts()
# Out:
# 1    171
# 2     15
# 4      1
# Name: price, dtype: int64

# %%
dataOri["price"].value_counts()
# Out:
# 15342    4
# 8921     2
# 18150    2
# 8845     2
# 8495     2
#         ..
# 45400    1
# 16503    1
# 5389     1
# 6189     1
# 22625    1
# Name: price, Length: 187, dtype: int64

# %%
data0["peak-rpm"]=data0["peak-rpm"].replace("?",6500)

# %%
data0.describe().T
# Out:
#                    count         mean         std      min      25%      50%  \
# symboling          205.0     0.834146    1.245307    -2.00     0.00     1.00
# normalized-losses  205.0   123.400000   31.805105    65.00   101.00   128.00
# wheel-base         205.0    98.756585    6.021776    86.60    94.50    97.00
# length             205.0   174.049268   12.337289   141.10   166.30   173.20
# width              205.0    65.907805    2.145204    60.30    64.10    65.50
# height             205.0    53.724878    2.443522    47.80    52.00    54.10
# curb-weight        205.0  2555.565854  520.680204  1488.00  2145.00  2414.00
# engine-size        205.0   126.907317   41.642693    61.00    97.00   120.00
# bore               205.0     3.314146    0.292665     2.53     3.13     3.31
# stroke             205.0     3.234439    0.347243     2.07     3.10     3.29
# compression-ratio  205.0    10.142537    3.972040     7.00     8.60     9.00
# horsepower         205.0   103.931707   39.654825    48.00    70.00    95.00
# peak-rpm           205.0  5138.780488  495.836563  4150.00  4800.00  5200.00
# city-mpg           205.0    25.219512    6.542142    13.00    19.00    24.00
# highway-mpg        205.0    30.751220    6.886443    16.00    25.00    30.00
#
#                        75%      max
# symboling             2.00     3.00
# normalized-losses   137.00   256.00
# wheel-base          102.40   120.90
# length              183.10   208.10
# width                66.90    72.30
# height               55.50    59.80
# curb-weight        2935.00  4066.00
# engine-size         141.00   326.00
# bore                  3.58     3.94
# stroke                3.41     4.17
# compression-ratio     9.40    23.00
# horsepower          116.00   288.00
# peak-rpm           5500.00  6600.00
# city-mpg             30.00    49.00
# highway-mpg          34.00    54.00

# %%
data0=dataOri.drop(columns="price")
#data01=pd.get_dummies(data0)
data0=data0.drop(columns=["make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location",
                         "fuel-system"])

# %%
data0=data0.drop(columns=["engine-type","num-of-cylinders",])

# %%
data0["normalized-losses"]=data0["normalized-losses"].replace("?",129)

# %%
data0["curb-weight"].value_counts()
# Out:
# 2385    4
# 1918    3
# 2275    3
# 1989    3
# 2410    2
#        ..
# 2370    1
# 2328    1
# 2833    1
# 2921    1
# 3062    1
# Name: curb-weight, Length: 171, dtype: int64

# %% [markdown]
# En este ejemplo de PCA utilizando la biblioteca Sklearn, utilizaremos un conjunto de datos altamente dimensional mostraremos
#
# Cómo se puede utilizar el PCA para visualizar el conjunto de datos de alta dimensión.
#
# Cómo PCA puede evitar el sobreajuste en un clasificador debido al conjunto de datos de alta dimensión.
#
# Cómo el PCA puede mejorar la velocidad del proceso de entrenamiento.
#
# Utilizaremos los paquetes sklearn, seaborn y bioinfokit (v2.0.2 o posterior) para el PCA y la visualización
#
# Así que empecemos.!!!!!!!!

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
dataOri["price"]=dataOri["price"].replace("?",15342)

# %%
dataOri["price"].value_counts()
# Out:
# 15342.0    4
# 8921.0     2
# 18150.0    2
# 8845.0     2
# 8495.0     2
#           ..
# 45400.0    1
# 16503.0    1
# 5389.0     1
# 6189.0     1
# 22625.0    1
# Name: price, Length: 187, dtype: int64

# %% [markdown]
# Visualización de un conjunto de datos de alta dimensión con PCA usando Sklearn
# Como hemos comentado anteriormente, no es posible para los humanos visualizar datos que tengan más de 3 dimensiones. En este conjunto de datos, hay N dimensiones. Reduzcamos la alta dimensionalidad del conjunto de datos utilizando PCA para visualizarlo tanto en 2D como en 3D.
#
# Normalización del conjunto de datos
# Es obligatorio estandarizar el conjunto de datos antes de aplicar PCA, de lo contrario, producirá resultados erróneos. Aquí utilizamos la función StandardScaler() del módulo sklearn.preprocessing para estandarizar los conjuntos de datos de entrenamiento y de prueba.

# %%
# this is an optional step
df_st =  StandardScaler().fit_transform(data0)  
pd.DataFrame(df_st, columns=data0.columns).head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width    height  \
# 0   1.743470           0.176503   -1.690772 -0.426521 -0.844782 -2.020417
# 1   1.743470           0.176503   -1.690772 -0.426521 -0.844782 -2.020417
# 2   0.133509           0.176503   -0.708596 -0.231513 -0.190566 -0.543527
# 3   0.938490           1.279650    0.173698  0.207256  0.136542  0.235942
# 4   0.938490           1.279650    0.107110  0.207256  0.230001  0.235942
#
#    curb-weight  engine-size      bore    stroke  compression-ratio  \
# 0    -0.014566     0.074449  0.533836 -1.600597          -0.288349
# 1    -0.014566     0.074449  0.533836 -1.600597          -0.288349
# 2     0.514882     0.604046 -2.172103  0.680036          -0.288349
# 3    -0.420797    -0.431076 -0.425231  0.477954          -0.035973
# 4     0.516807     0.218885 -0.425231  0.477954          -0.540725
#
#    horsepower  peak-rpm  city-mpg  highway-mpg
# 0    0.178682 -0.280577 -0.646553    -0.546059
# 1    0.178682 -0.280577 -0.646553    -0.546059
# 2    1.265694 -0.280577 -0.953012    -0.691627
# 3   -0.048832  0.730289 -0.186865    -0.109354
# 4    0.279799  0.730289 -1.106241    -1.273900

# %% [markdown]
# Estandarización
#
# El conjunto de datos de estandarización con escala (media=0, varianza=1) es necesario ya que elimina los sesgos de las variables originales. Por ejemplo, cuando los datos de cada variable se recogen en unidades diferentes.
# Las variables estandarizadas no tendrán unidades y tendrán una varianza similar.
# La estandarización es un método aconsejable para la transformación de datos cuando las variables del conjunto de datos original se han medido en una escala significativamente diferente.
# En algunos casos, no es necesario estandarizar el conjunto de datos, ya que la variación original del conjunto de datos es importante (Gewers et al., 2018)
#
#
# ¡Realice PCA usando Scikit-learn!

# %%
pca_out = PCA(n_components=10).fit(df_st)

# get the component variance
# Proportion of Variance (from PC1 to PC6)
pca_out.explained_variance_ratio_
# Out:
# array([0.44653143, 0.19193041, 0.08787014, 0.06131274, 0.05755131,
#        0.03724415, 0.03010667, 0.02928267, 0.01736405, 0.01653873])

# %%
# Cumulative proportion of variance (from PC1 to PC6)   
np.cumsum(pca_out.explained_variance_ratio_)
# Out:
# array([0.44653143, 0.63846184, 0.72633198, 0.78764472, 0.84519603,
#        0.88244019, 0.91254686, 0.94182953, 0.95919358, 0.97573232])

# %%
# component loadings or weights (correlation coefficient between original variables and the component) 
# component loadings represents the elements of the eigenvector
# the squared loadings within the PCs always sums to 1
loadings = pca_out.components_
num_pc = pca_out.n_features_
pc_list = ["PC"+str(i) for i in list(range(1, num_pc+1))]
loadings_df = pd.DataFrame.from_dict(dict(zip(pc_list, loadings)))
loadings_df['variable'] = data0.columns.values
loadings_df = loadings_df.set_index('variable')
loadings_df
# Out:
#                         PC1       PC2       PC3       PC4       PC5       PC6  \
# variable
# symboling         -0.109237  0.399653  0.321658  0.238766  0.140578 -0.117978
# normalized-losses  0.037671  0.349381  0.382710  0.362280 -0.349485 -0.475733
# wheel-base         0.316861 -0.237641 -0.043663  0.119873 -0.257276 -0.107729
# length             0.354632 -0.107206 -0.040884  0.121858 -0.163469 -0.072533
# width              0.345107 -0.031641  0.098200  0.099133 -0.138580  0.193479
# height             0.133064 -0.404787 -0.293551  0.107643 -0.229812 -0.301652
# curb-weight        0.373179  0.001073  0.086401  0.064338 -0.005050  0.108384
# engine-size        0.330840  0.083624  0.207267 -0.168112  0.196025  0.136411
# bore               0.266825 -0.048535  0.001372 -0.159868  0.486738 -0.317937
# stroke             0.065995 -0.115920  0.481375 -0.729644 -0.323944 -0.185583
# compression-ratio  0.021467 -0.360176  0.473344  0.342095 -0.055917  0.493718
# horsepower         0.296122  0.281382  0.024275 -0.130490  0.160220  0.290013
# peak-rpm          -0.092750  0.357297 -0.267762 -0.186473 -0.531013  0.345827
# city-mpg          -0.311751 -0.274691  0.191147 -0.020888  0.029512  0.028389
# highway-mpg       -0.324761 -0.224910  0.188811 -0.038828  0.034921  0.017823
#
#                         PC7       PC8       PC9      PC10
# variable
# symboling         -0.621753 -0.304292  0.079077  0.318769
# normalized-losses  0.269920  0.313393 -0.198408 -0.142630
# wheel-base         0.164088 -0.000525  0.165716  0.236341
# length            -0.059187 -0.008357  0.164636  0.097810
# width              0.046365 -0.003088  0.292941  0.529600
# height            -0.498132 -0.042844 -0.517140  0.004702
# curb-weight        0.003004 -0.056029 -0.088085 -0.073955
# engine-size        0.130911 -0.009050 -0.465852  0.189079
# bore              -0.270853  0.637297  0.268527 -0.057107
# stroke            -0.132204 -0.169385  0.093827 -0.115786
# compression-ratio -0.241904  0.168502  0.055289 -0.402705
# horsepower        -0.011121  0.088125 -0.422268 -0.000630
# peak-rpm          -0.289682  0.459009  0.031633  0.072053
# city-mpg           0.087144  0.228496 -0.164535  0.376190
# highway-mpg        0.041440  0.264873 -0.177311  0.406635

# %%
loadings_df[(loadings_df["PC1"]>0.2)|(loadings_df["PC1"]<-0.2)]["PC1"]
# Out:
# variable
# wheel-base     0.316861
# length         0.354632
# width          0.345107
# curb-weight    0.373179
# engine-size    0.330840
# bore           0.266825
# horsepower     0.296122
# city-mpg      -0.311751
# highway-mpg   -0.324761
# Name: PC1, dtype: float64

# %%
loadings_df[(loadings_df["PC6"]>0.02)|(loadings_df["PC6"]<-0.02)]["PC6"]
# Out:
# variable
# symboling           -0.117978
# normalized-losses   -0.475733
# wheel-base          -0.107729
# length              -0.072533
# width                0.193479
# height              -0.301652
# curb-weight          0.108384
# engine-size          0.136411
# bore                -0.317937
# stroke              -0.185583
# compression-ratio    0.493718
# horsepower           0.290013
# peak-rpm             0.345827
# city-mpg             0.028389
# Name: PC6, dtype: float64

# %% [markdown]
# Algunas variables correlacionan bien con algunas componentes **positivamente** mientras que otras correlacional **negativamente**.

# %%
# get correlation matrix plot for loadings
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,12))
ax = sns.heatmap(loadings_df, annot=True, cmap='Greens')
plt.show()

# %%
loadings_df.columns
# Out:
# Index(['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10'], dtype='object')

# %%
abs(loadings_df["PC1"]).mean()
# Out:
# 0.22535073814977988

# %%
pca_out.explained_variance_ratio_, pca_out.explained_variance_ratio_[:4].sum()
# Out:
# (array([0.44653143, 0.19193041, 0.08787014, 0.06131274, 0.05755131,
#         0.03724415, 0.03010667, 0.02928267, 0.01736405, 0.01653873]),
#  0.7876447249505142)

# %% [markdown]
# **Retención de los componentes principales (PC)**
#
# Cuando el número de PCs es igual al número de variables originales, deberíamos mantener sólo los PCs que explican la mayor parte de la varianza (70-95%) para facilitar la interpretación. Cuantas más PCs se incluyan que expliquen la mayor parte de la variación en los datos originales.
#
# Los valores propios (varianza explicada por cada PC) de las PC pueden ayudar a retener el número de PC. Generalmente, los PC con valores propios > 1 contribuyen a una mayor varianza y deberían retenerse para el análisis posterior.
#
# El gráfico Scree (para la prueba del codo) es otra técnica gráfica útil para retener las PC. Mantenemos los PCs en los que hay un cambio brusco en la pendiente de la línea que conecta los PCs adyacentes.

# %%
plt.figure(figsize=(12,5))
plt.bar(loadings_df.columns,pca_out.explained_variance_ratio_*100)
plt.ylabel("Proporción de Varianza (%)")
plt.xlabel("PCs")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.bar(loadings_df.columns,np.cumsum(pca_out.explained_variance_ratio_*100))
plt.ylabel("Proporción Acumulada de la Varianza (%)")
plt.xlabel("PCs")
plt.show()

# %%
# get eigenvalues (variance explained by each PC)  
pca_out.explained_variance_

# get scree plot (for scree or elbow test)
from bioinfokit.visuz import cluster
cluster.screeplot(obj=[loadings_df.columns,pca_out.explained_variance_ratio_],show=True,dim=(12,5),axlabelfontsize=14,)
plt.show()
# Scree plot will be saved in the same directory with name screeplot.png

# %%
# get PCA loadings plots (2D and 3D)
# 2D
cluster.pcaplot(x=loadings[0], y=loadings[1], labels=data0.columns.values,
                show=True,dim=(12,10),axlabelfontsize=14,
    var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
    var2=round(pca_out.explained_variance_ratio_[1]*100, 2))

# %%
# 3D
cluster.pcaplot(x=loadings[0], y=loadings[1], z=loadings[2],  labels=data0.columns.values, 
                show=True,dim=(12,10),axlabelfontsize=14,
                var1=round(pca_out.explained_variance_ratio_[0]*100, 2), 
                var2=round(pca_out.explained_variance_ratio_[1]*100, 2), 
                var3=round(pca_out.explained_variance_ratio_[2]*100, 2))

# %% [markdown]
# En biplot, las cargas y las puntuaciones de las PCs se representan en una sola figura los biplots son útiles para visualizar las relaciones entre las variables y las observaciones.

# %%
cmap=plt.cm.Blues
norm=plt.Normalize(vmin=0,vmax=20000)

# %%
# get PC scores
pca_scores = PCA().fit_transform(df_st)

# get 2D biplot
cluster.biplot(cscore=pca_scores, loadings=loadings, labels=data0.columns.values,dotsize=16,
               colordot=cmap(norm(dataOri["price"])),arrowcolor='r',arrowlinewidth=0.9,arrowlinestyle='--',show=True,dim=(12,10),axlabelfontsize=14,
               var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
               var2=round(pca_out.explained_variance_ratio_[1]*100, 2))

# %% [markdown]
# # Observaciones
#
# Los vehículos highway-mpg (Autopista)y city-mpg (ciudad), solo los más **económicos**, mientras que los más **costosos** son los de normalized-losses (pérdidas-normalizadas), horsepower (caballos de fuerza), engine-size (tamaño del motor) y curb-weight (peso en vacío)

# %%
import statsmodels.api as sm

# %%
x=dataOri[["horsepower","engine-size","bore","width","length","wheel-base","city-mpg","highway-mpg"]].astype(np.float64)
y=dataOri["price"]

# %%
#dataOri["wheel-base"].value_counts()

# %%
#x=sm.add_constant(x)
model=sm.OLS(y,x).fit()
predic=model.predict(x)
print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.940
# Model:                            OLS   Adj. R-squared (uncentered):              0.938
# Method:                 Least Squares   F-statistic:                              388.8
# Date:                Sat, 04 Jun 2022   Prob (F-statistic):                   3.03e-116
# Time:                        15:05:03   Log-Likelihood:                         -1978.4
# No. Observations:                 205   AIC:                                      3973.
# Df Residuals:                     197   BIC:                                      3999.
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# horsepower     25.3725     16.848      1.506      0.134      -7.854      58.599
# engine-size   122.4132     12.927      9.470      0.000      96.921     147.906
# bore        -2389.5839   1311.510     -1.822      0.070   -4975.985     196.817
# width        -122.1722    162.448     -0.752      0.453    -442.532     198.187
# length          8.1985     60.422      0.136      0.892    -110.958     127.355
# wheel-base    152.8611    112.402      1.360      0.175     -68.804     374.526
# city-mpg       10.3186    207.479      0.050      0.960    -398.846     419.483
# highway-mpg  -185.8959    183.388     -1.014      0.312    -547.551     175.759
# ==============================================================================
# Omnibus:                       32.160   Durbin-Watson:                   0.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.314
# Skew:                           0.796   Prob(JB):                     1.32e-13
# Kurtosis:                       5.100   Cond. No.                     1.34e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
dataOri["bore"]=dataOri["bore"].replace("?",3.18)
#dataOri["price"].value_counts()

# %%
dataOri.cov()
# Out:
#                     symboling    wheel-base        length         width  \
# symboling            1.550789     -3.989099     -5.494240     -0.622229
# wheel-base          -3.989099     36.261782     64.975189     10.271615
# length              -5.494240     64.975189    152.208688     22.261035
# width               -0.622229     10.271615     22.261035      4.601900
# height              -1.646344      8.673144     14.802788      1.463579
# curb-weight       -147.636083   2434.296746   5638.336200    968.445072
# engine-size         -5.486035    142.766545    351.081549     65.697786
# compression-ratio   -0.883009      5.974562      7.762938      1.543367
# city-mpg            -0.291846    -18.532090    -54.150574     -9.019859
# highway-mpg          0.296772    -22.562324    -59.868075    -10.004421
# price             -819.481851  27547.772009  65984.653274  12339.958056
# price0            -819.481851  27547.772009  65984.653274  12339.958056
#
#                         height   curb-weight    engine-size  \
# symboling            -1.646344 -1.476361e+02      -5.486035
# wheel-base            8.673144  2.434297e+03     142.766545
# length               14.802788  5.638336e+03     351.081549
# width                 1.463579  9.684451e+02      65.697786
# height                5.970800  3.760540e+02       6.832709
# curb-weight         376.053991  2.711079e+05   18443.028192
# engine-size           6.832709  1.844303e+04    1734.113917
# compression-ratio     2.535285  3.130407e+02       4.792050
# city-mpg             -0.777547 -2.580027e+03    -178.077594
# highway-mpg          -1.806526 -2.859417e+03    -194.278073
# price              2496.035758  3.362799e+06  282442.803539
# price0             2496.035758  3.362799e+06  282442.803539
#
#                    compression-ratio      city-mpg   highway-mpg  \
# symboling                  -0.883009     -0.291846      0.296772
# wheel-base                  5.974562    -18.532090    -22.562324
# length                      7.762938    -54.150574    -59.868075
# width                       1.543367     -9.019859    -10.004421
# height                      2.535285     -0.777547     -1.806526
# curb-weight               313.040714  -2580.026781  -2859.417360
# engine-size                 4.792050   -178.077594   -194.278073
# compression-ratio          15.777104      8.437578      7.254115
# city-mpg                    8.437578     42.799617     43.760760
# highway-mpg                 7.254115     43.760760     47.423099
# price                    2173.074567 -34274.354615 -37282.092874
# price0                   2173.074567 -34274.354615 -37282.092874
#
#                           price        price0
# symboling         -8.194819e+02 -8.194819e+02
# wheel-base         2.754777e+04  2.754777e+04
# length             6.598465e+04  6.598465e+04
# width              1.233996e+04  1.233996e+04
# height             2.496036e+03  2.496036e+03
# curb-weight        3.362799e+06  3.362799e+06
# engine-size        2.824428e+05  2.824428e+05
# compression-ratio  2.173075e+03  2.173075e+03
# city-mpg          -3.427435e+04 -3.427435e+04
# highway-mpg       -3.728209e+04 -3.728209e+04
# price              6.200514e+07  6.200514e+07
# price0             6.200514e+07  6.200514e+07

# %%
# !dir
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 56F9-23DD
#
#  Directorio de C:\Users\hmarbello\AppData\Local\Programs\Python\Python310\Scripts
#
# 04/06/2022  03:07 p. m.    <DIR>          .
# 03/05/2022  10:26 a. m.    <DIR>          ..
# 04/06/2022  08:25 a. m.    <DIR>          .ipynb_checkpoints
# 24/05/2022  01:30 p. m.             1.612 ACU.txt
# 07/05/2022  10:59 a. m.           771.257 AD_ClaseSabadoUC.ipynb
# 06/05/2022  08:19 p. m.         3.900.764 AD_UltimaClaseViernes.ipynb
# 24/05/2022  01:59 p. m.                62 AGENDA.csv
# 20/05/2022  05:20 p. m.            80.413 Archivos.ipynb
# 24/05/2022  01:30 p. m.               677 A¥O.txt
# 24/05/2022  02:13 p. m.               242 BDLubriRepuestos.csv
# 24/05/2022  01:31 p. m.             1.015 BECA.txt
# 20/01/2022  02:22 p. m.             1.089 beeline
# 20/01/2022  02:22 p. m.             1.064 beeline.cmd
# 11/02/2022  02:16 p. m.           106.374 black-primer.exe
# 11/02/2022  02:16 p. m.           106.379 black.exe
# 11/02/2022  02:16 p. m.           106.380 blackd.exe
# 03/05/2022  10:26 a. m.           106.372 bokeh.exe
# 23/05/2022  03:37 p. m.            26.842 Bomba (3) (1) (2) (6).ipynb
# 22/04/2022  07:15 p. m.             1.045 browse-script.py
# 22/04/2022  07:15 p. m.            74.752 browse.exe
# 27/05/2022  02:50 p. m.               138 BUZONSUGERENCIAS.txt
# 27/05/2022  02:26 p. m.                 1 cantidad_usuarios.txt
# 21/05/2022  03:25 p. m.         1.244.737 ClaseSabado1M.ipynb
# 20/05/2022  08:25 p. m.         1.249.986 ClaseViernes1Prueba.ipynb
# 24/05/2022  01:52 p. m.               452 CLIENTES BANCO DEALER.csv
# 03/05/2022  10:26 a. m.           106.375 colorcet.exe
# 23/05/2022  03:33 p. m.                68 contabilidad.txt
# 27/05/2022  02:50 p. m.               262 CURSOS.csv
# 25/03/2022  07:48 p. m.             6.570 cv
# 03/05/2022  10:26 a. m.           106.388 dask-scheduler.exe
# 03/05/2022  10:26 a. m.           106.382 dask-ssh.exe
# 03/05/2022  10:26 a. m.           106.385 dask-worker.exe
# 03/05/2022  10:26 a. m.           106.377 datashader.exe
# 27/05/2022  03:05 p. m.                 0 datos.csv
# 25/05/2022  07:30 a. m.               133 datos.txt
# 06/05/2022  08:18 p. m.         3.688.877 df_csv.html
# 19/05/2022  03:53 p. m.            11.582 DiccTuplas.ipynb
# 20/01/2022  02:22 p. m.            10.965 docker-image-tool.sh
# 02/05/2022  02:55 p. m.            43.114 EstaNotasParciales.ipynb
# 03/05/2022  10:38 a. m.           106.422 estimator_ckpt_converter.exe
# 27/05/2022  02:50 p. m.             1.205 ESTUDIANTES.csv
# 03/05/2022  10:21 a. m.           106.375 f2py.exe
# 28/04/2022  03:01 p. m.            12.303 FavorMEA.ipynb
# 24/05/2022  01:30 p. m.             1.327 FECH.txt
# 29/04/2022  02:07 p. m.             8.010 fechaAcual.ipynb
# 20/01/2022  02:22 p. m.             1.935 find-spark-home
# 20/01/2022  02:22 p. m.             2.685 find-spark-home.cmd
# 23/04/2022  10:51 a. m.             4.018 find_spark_home.py
# 22/04/2022  07:15 p. m.             1.039 fitter-script.py
# 22/04/2022  07:15 p. m.            74.752 fitter.exe
# 25/03/2022  07:47 p. m.           106.376 fonttools.exe
# 28/04/2022  09:03 a. m.                34 foo.txt
# 27/04/2022  06:52 a. m.             6.052 FunGrupoM.ipynb
# 27/04/2022  06:58 a. m.             3.293 FunGrupoR.ipynb
# 05/05/2022  08:58 a. m.            21.755 FunYarchivoGrupoQ.ipynb
# 17/05/2022  01:43 p. m.            21.958 FunYarchivoGrupoR.ipynb
# 03/05/2022  10:37 a. m.           106.392 google-oauthlib-tool.exe
# 24/05/2022  01:30 p. m.               926 GRA.txt
# 23/05/2022  03:44 p. m.            10.365 GrMi.png
# 29/04/2022  07:01 a. m.                27 holamundo.txt
# 03/05/2022  10:26 a. m.           106.380 holoviews.exe
# 30/03/2022  02:55 p. m.             5.618 Horario.xlsx
# 29/04/2022  01:03 p. m.           157.363 Horarios202210.ipynb
# 27/05/2022  02:26 p. m.    <DIR>          Humberto
# 25/03/2022  08:30 p. m.           106.400 imageio_download_bin.exe
# 25/03/2022  08:30 p. m.           106.396 imageio_remove_bin.exe
# 23/05/2022  09:44 a. m.           554.973 Imagen de graficas en python.png
# 03/05/2022  10:38 a. m.           106.406 import_pb_to_tensorboard.exe
# 20/05/2022  02:37 p. m.               959 Info.csv
# 27/05/2022  02:16 p. m.                47 Info.txt
# 18/05/2022  06:58 a. m.                 0 InfoCSV.csv
# 27/05/2022  02:50 p. m.             2.290 INFORMACION.csv
# 17/05/2022  02:32 p. m.                42 Inventario.txt
# 27/05/2022  02:49 p. m.               175 Investigacion.csv
# 11/02/2022  02:16 p. m.           106.383 ipython.exe
# 11/02/2022  02:16 p. m.           106.383 ipython3.exe
# 23/04/2022  10:51 a. m.             1.749 jp.py
# 11/02/2022  02:16 p. m.           106.372 jsonschema.exe
# 11/02/2022  02:16 p. m.           106.392 jupyter-bundlerextension.exe
# 11/02/2022  02:16 p. m.           106.394 jupyter-dejavu.exe
# 11/02/2022  02:16 p. m.           106.370 jupyter-execute.exe
# 11/02/2022  02:16 p. m.           106.382 jupyter-kernel.exe
# 11/02/2022  02:16 p. m.           106.420 jupyter-kernelspec.exe
# 11/02/2022  02:16 p. m.           106.378 jupyter-migrate.exe
# 11/02/2022  02:16 p. m.           106.380 jupyter-nbconvert.exe
# 11/02/2022  02:16 p. m.           106.379 jupyter-nbextension.exe
# 11/02/2022  02:16 p. m.           106.378 jupyter-notebook.exe
# 11/02/2022  02:16 p. m.           106.399 jupyter-run.exe
# 11/02/2022  02:16 p. m.           106.383 jupyter-serverextension.exe
# 11/02/2022  02:16 p. m.           106.383 jupyter-troubleshoot.exe
# 11/02/2022  02:16 p. m.           106.411 jupyter-trust.exe
# 11/02/2022  02:16 p. m.           106.378 jupyter.exe
# 25/05/2022  07:46 a. m.               321 LISTAAGRUPOR
# 25/05/2022  07:46 a. m.               278 LISTAAGRUPOU
# 20/01/2022  02:22 p. m.             2.337 load-spark-env.cmd
# 20/01/2022  02:22 p. m.             2.435 load-spark-env.sh
# 23/05/2022  09:39 p. m.                23 Login.txt
# 25/03/2022  08:30 p. m.           106.374 lsm2bin.exe
# 24/05/2022  01:31 p. m.             1.163 LUG.txt
# 20/05/2022  08:15 p. m.             3.979 Mall_Customers.csv
# 22/04/2022  08:27 p. m.           514.118 MAP_AD_ViernesCalse3.ipynb
# 03/05/2022  10:25 a. m.           106.373 markdown_py.exe
# 03/06/2022  07:22 p. m.            17.482 ME_Clase2V.ipynb
# 04/06/2022  10:25 a. m.           785.213 ME_Clase2V_1.ipynb
# 04/06/2022  03:07 p. m.           470.790 ME_TareaClase2.ipynb
# 23/05/2022  04:38 p. m.                 0 mi_fichero
# 28/04/2022  06:59 a. m.                46 myfile.txt
# 27/05/2022  02:03 p. m.                87 my_page
# 24/05/2022  01:30 p. m.             1.261 NDOC.txt
# 24/05/2022  01:30 p. m.             2.844 NOM.txt
# 03/05/2022  10:25 a. m.           106.403 normalizer.exe
# 25/05/2022  01:20 p. m.               112 notas.txt
# 23/05/2022  02:29 p. m.               617 notas_estudiantes.txt
# 03/05/2022  10:25 a. m.               242 numba
# 24/05/2022  01:31 p. m.             6.500 OBSERVACIONES.txt
# 23/05/2022  09:27 a. m.            10.239 ola.txt
# 03/05/2022  10:26 a. m.           106.371 panel.exe
# 25/03/2022  07:46 p. m.           106.380 pip.exe
# 25/03/2022  07:46 p. m.           106.380 pip3.10.exe
# 25/03/2022  07:46 p. m.           106.380 pip3.exe
# 24/05/2022  01:31 p. m.               582 PROM.txt
# 03/05/2022  10:25 a. m.               108 pycc
# 03/05/2022  10:25 a. m.           106.371 pyct.exe
# 25/03/2022  07:47 p. m.           106.373 pyftmerge.exe
# 25/03/2022  07:47 p. m.           106.374 pyftsubset.exe
# 11/02/2022  02:16 p. m.           106.374 pygmentize.exe
# 03/05/2022  10:37 a. m.           106.371 pyrsa-decrypt.exe
# 03/05/2022  10:37 a. m.           106.371 pyrsa-encrypt.exe
# 03/05/2022  10:37 a. m.           106.369 pyrsa-keygen.exe
# 03/05/2022  10:37 a. m.           106.392 pyrsa-priv2pub.exe
# 03/05/2022  10:37 a. m.           106.365 pyrsa-sign.exe
# 03/05/2022  10:37 a. m.           106.369 pyrsa-verify.exe
# 20/01/2022  02:22 p. m.             2.636 pyspark
# 20/01/2022  02:22 p. m.             1.170 pyspark.cmd
# 20/01/2022  02:22 p. m.             1.542 pyspark2.cmd
# 11/02/2022  02:15 p. m.            26.854 pywin32_postinstall.py
# 11/02/2022  02:15 p. m.             3.521 pywin32_testall.py
# 20/01/2022  02:22 p. m.             1.030 run-example
# 20/01/2022  02:22 p. m.             1.223 run-example.cmd
# 23/05/2022  04:26 p. m.                 0 rv.txt
# 09/04/2022  03:37 p. m.           563.249 Sabado2_2.ipynb
# 07/03/2022  01:42 p. m.             3.063 SacarDigitos.ipynb
# 04/04/2022  03:07 p. m.            85.922 salonesT.xlsx
# 03/05/2022  10:38 a. m.           106.397 saved_model_cli.exe
# 11/02/2022  02:16 p. m.           106.377 send2trash.exe
# 25/03/2022  08:30 p. m.           106.379 skivi.exe
# 20/01/2022  02:22 p. m.             3.539 spark-class
# 20/01/2022  02:22 p. m.             1.180 spark-class.cmd
# 20/01/2022  02:22 p. m.             2.812 spark-class2.cmd
# 20/01/2022  02:22 p. m.             3.122 spark-shell
# 20/01/2022  02:22 p. m.             1.178 spark-shell.cmd
# 20/01/2022  02:22 p. m.             1.818 spark-shell2.cmd
# 20/01/2022  02:22 p. m.             1.065 spark-sql
# 20/01/2022  02:22 p. m.             1.173 spark-sql.cmd
# 20/01/2022  02:22 p. m.             1.118 spark-sql2.cmd
# 20/01/2022  02:22 p. m.             1.040 spark-submit
# 20/01/2022  02:22 p. m.             1.180 spark-submit.cmd
# 20/01/2022  02:22 p. m.             1.155 spark-submit2.cmd
# 20/01/2022  02:22 p. m.             1.039 sparkR
# 20/01/2022  02:22 p. m.             1.168 sparkR.cmd
# 20/01/2022  02:22 p. m.             1.097 sparkR2.cmd
# 27/05/2022  03:16 p. m.           158.780 sProyecto.ipynb
# 03/06/2022  07:58 p. m.           106.368 tabulate.exe
# 08/04/2022  02:36 p. m.             4.703 Taller1C2_202210.ipynb
# 23/04/2022  02:00 p. m.           349.210 Tarea3AD.ipynb
# 06/05/2022  07:13 p. m.         1.767.169 Tarea_1_Modulo1_AnalisisDeDatos.ipynb
# 24/05/2022  01:31 p. m.               485 TDOC.txt
# 03/05/2022  10:38 a. m.           106.382 tensorboard.exe
# 03/05/2022  10:38 a. m.           106.395 tflite_convert.exe
# 03/05/2022  10:38 a. m.           106.407 tf_upgrade_v2.exe
# 25/03/2022  08:30 p. m.           106.378 tiff2fsspec.exe
# 25/03/2022  08:30 p. m.           106.378 tiffcomment.exe
# 25/03/2022  08:30 p. m.           106.366 tifffile.exe
# 03/05/2022  10:38 a. m.           106.395 toco.exe
# 03/05/2022  10:38 a. m.           106.402 toco_from_protos.exe
# 03/05/2022  10:21 a. m.           106.366 tqdm.exe
# 25/03/2022  07:47 p. m.           106.371 ttx.exe
# 05/05/2022  02:33 p. m.         6.364.876 UMAP.ipynb
# 09/05/2022  03:48 p. m.           117.089 UMAP2.ipynb
# 25/05/2022  04:55 p. m.    <DIR>          Untitled Folder
# 11/02/2022  03:01 p. m.             6.294 Untitled.ipynb
# 14/02/2022  04:05 p. m.             1.936 Untitled1.ipynb
# 09/03/2022  02:22 p. m.             1.927 Untitled10.ipynb
# 09/03/2022  03:46 p. m.             6.287 Untitled11.ipynb
# 09/03/2022  04:41 p. m.             1.185 Untitled12.ipynb
# 09/03/2022  04:51 p. m.             2.287 Untitled13.ipynb
# 15/03/2022  09:15 a. m.             2.193 Untitled14.ipynb
# 15/03/2022  02:53 p. m.             3.111 Untitled15.ipynb
# 16/03/2022  03:54 p. m.             3.550 Untitled16.ipynb
# 16/03/2022  04:57 p. m.             2.210 Untitled17.ipynb
# 25/03/2022  08:34 p. m.            23.214 Untitled18.ipynb
# 31/03/2022  07:25 a. m.            34.819 Untitled19.ipynb
# 16/02/2022  03:14 p. m.               589 Untitled2.ipynb
# 31/03/2022  07:21 a. m.            34.397 Untitled20.ipynb
# 08/04/2022  02:48 p. m.             2.779 Untitled21.ipynb
# 30/03/2022  09:47 a. m.             5.644 Untitled22.ipynb
# 22/04/2022  01:56 p. m.            26.662 Untitled23.ipynb
# 27/04/2022  04:44 p. m.             6.352 Untitled24.ipynb
# 19/05/2022  03:16 p. m.             3.267 Untitled25.ipynb
# 29/04/2022  01:54 p. m.               589 Untitled26.ipynb
# 03/05/2022  10:38 a. m.             4.778 Untitled27.ipynb
# 17/05/2022  02:12 p. m.            31.529 Untitled28.ipynb
# 17/05/2022  02:38 p. m.             8.796 Untitled29.ipynb
# 16/02/2022  04:40 p. m.             4.478 Untitled3.ipynb
# 19/05/2022  04:18 p. m.             5.483 Untitled30.ipynb
# 03/06/2022  05:01 p. m.            10.146 Untitled31.ipynb
# 18/02/2022  11:03 a. m.             2.359 Untitled4.ipynb
# 21/02/2022  08:16 a. m.             1.216 Untitled5.ipynb
# 23/02/2022  04:54 p. m.             2.711 Untitled6.ipynb
# 28/02/2022  08:57 a. m.               589 Untitled7.ipynb
# 02/03/2022  01:15 p. m.               977 Untitled8.ipynb
# 08/03/2022  10:33 a. m.             7.758 Untitled9.ipynb
# 27/05/2022  02:26 p. m.                18 usuarios.txt
# 31/03/2022  04:17 p. m.             1.907 vba_extract.py
# 24/05/2022  01:25 p. m.               489 ventas.txt
# 09/04/2022  11:13 a. m.           177.127 ViernesC2_AD.ipynb
# 08/04/2022  08:36 a. m.           106.397 virtualenv.exe
# 03/05/2022  10:37 a. m.           106.367 wheel.exe
# 23/04/2022  10:51 a. m.    <DIR>          __pycache__
#              213 archivos     30.866.894 bytes
#                6 dirs  49.877.340.160 bytes libres
